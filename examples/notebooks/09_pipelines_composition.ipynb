# %% [markdown]
# # Pipelines and CompositionThis notebook demonstrates how to compose transformers and forecasters using pipelines.

# %% [raw]
# import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport timesmith as ts

# %% [markdown]
# ## Simple Pipeline

# %% [raw]
# # Create datadates = pd.date_range('2020-01-01', periods=200, freq='D')y = pd.Series(np.random.randn(200).cumsum() + 100, index=dates)# Create pipeline: outlier removal -> missing value fillingpipeline = ts.make_pipeline([    ts.OutlierRemover(method='iqr'),    ts.MissingValueFiller(method='linear')])y_transformed = pipeline.fit_transform(y)print(f"Original: {len(y)} points")print(f"Transformed: {len(y_transformed)} points")

# %% [markdown]
# ## Forecaster Pipeline

# %% [raw]
# # Create forecaster pipeline: preprocessing -> forecastingforecaster_pipeline = ts.make_forecaster_pipeline(    transformer=ts.OutlierRemover(method='iqr'),    forecaster=ts.SimpleMovingAverageForecaster(window=7))# Fit and predictforecaster_pipeline.fit(y)forecast = forecaster_pipeline.predict(fh=30)print(f"Forecast shape: {forecast.predicted.shape}")

# %% [markdown]
# ## Feature Union

# %% [raw]
# # Combine multiple featurizersfrom timesmith.compose import FeatureUnionfeature_union = FeatureUnion([    ('lags', ts.LagFeaturizer(lags=[1, 2, 3])),    ('rolling', ts.RollingFeaturizer(window=7, functions=['mean', 'std'])),    ('time', ts.TimeFeaturizer(features=['day_of_week', 'month']))])features = feature_union.fit_transform(y)print(f"Combined features shape: {features.shape}")

# %% [markdown]
# ## Adapter

# %% [raw]
# # Use adapter to convert between scitypesfrom timesmith.compose import Adapter# Series to Table adapterseries_to_table = Adapter(from_scitype='SeriesLike', to_scitype='TableLike')table_data = series_to_table.fit_transform(y)print(f"Table shape: {table_data.shape}")print(f"Table columns: {list(table_data.columns)}")
