# %% [markdown]
# # Network Analysis for Time SeriesThis notebook demonstrates network-based analysis of time series.

# %% [raw]
# import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport timesmith as ts

# %% [markdown]
# ## Creating Time Series

# %% [raw]
# # Create sample time seriesdates = pd.date_range('2020-01-01', periods=500, freq='D')y = pd.Series(np.random.randn(500).cumsum() + 100, index=dates)print(f"Time series length: {len(y)}")

# %% [markdown]
# ## Horizontal Visibility Graph

# %% [raw]
# # Build HVGhvg_featurizer = ts.HVGFeaturizer(weighted=False, include_degrees=True)hvg_features = hvg_featurizer.fit_transform(y)print(f"HVG features shape: {hvg_features.shape}")print(f"Features: {list(hvg_features.columns)}")hvg_features.head()

# %% [markdown]
# ## Natural Visibility Graph

# %% [raw]
# # Build NVGnvg_featurizer = ts.NVGFeaturizer(weighted=False, include_degrees=True)nvg_features = nvg_featurizer.fit_transform(y)print(f"NVG features shape: {nvg_features.shape}")nvg_features.head()

# %% [markdown]
# ## Recurrence Network

# %% [raw]
# # Recurrence networktry:    recurrence_featurizer = ts.RecurrenceNetworkFeaturizer(        threshold=0.5, embedding_dimension=2, time_delay=1    )    recurrence_features = recurrence_featurizer.fit_transform(y)        print(f"Recurrence features shape: {recurrence_features.shape}")    recurrence_features.head()except Exception as e:    print(f"Recurrence network not available: {e}")

# %% [markdown]
# ## Transfer Entropy

# %% [raw]
# # Create two related time seriesx = y + 0.1 * np.random.randn(len(y))# Compute transfer entropyte = ts.transfer_entropy(x, y, lag=1, bins=10)print(f"Transfer entropy from X to Y: {te:.4f}")

# %% [markdown]
# ## Windowed Network Analysis

# %% [raw]
# # Windowed network statisticstry:    window_stats = ts.build_windows(        y.values, window=100, step=10, method='hvg', output='stats'    )        print(f"Number of windows: {len(window_stats['n_nodes'])}")    print(f"Average nodes per window: {window_stats['n_nodes'].mean():.1f}")    print(f"Average edges per window: {window_stats['n_edges'].mean():.1f}")except Exception as e:    print(f"Windowed analysis not available: {e}")

# %% [markdown]
# ## Multiscale Analysis

# %% [raw]
# # Multiscale graph analysistry:    multiscale = ts.MultiscaleGraphs(method='hvg', scales=[1, 2, 4, 8])    signature = multiscale.fit_transform(y.values)        print(f"Scale signature features: {list(signature.keys())}")    for feature, values in signature.items():        print(f"{feature}: {values}")except Exception as e:    print(f"Multiscale analysis not available: {e}")
