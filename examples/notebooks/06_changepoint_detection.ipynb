# %% [markdown]
# # Change Point DetectionThis notebook demonstrates change point detection methods.

# %% [raw]
# import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport timesmith as ts

# %% [markdown]
# ## Creating Data with Change Points

# %% [raw]
# # Create data with change pointsnp.random.seed(42)dates = pd.date_range('2020-01-01', periods=200, freq='D')# Create series with mean shiftsy1 = np.random.randn(50).cumsum() + 100y2 = np.random.randn(50).cumsum() + 120  # Mean shift y3 = np.random.randn(50).cumsum() + 90   # Mean shifty4 = np.random.randn(50).cumsum() + 110  # Mean shifty = pd.Series(np.concatenate([y1, y2, y3, y4]), index=dates)print(f"True change points at indices: 50, 100, 150")

# %% [markdown]
# ## PELT Detector

# %% [raw]
# # PELT change point detectiontry:    pelt = ts.PELTDetector(penalty=10)    pelt.fit(y)    changepoints = pelt.predict(y)        print(f"Change points detected: {changepoints.sum()}")    print(f"Change point indices: {y.index[changepoints].tolist()}")except Exception as e:    print(f"PELT not available: {e}")

# %% [markdown]
# ## CUSUM Detector

# %% [raw]
# # CUSUM detectortry:    cusum = ts.CUSUMDetector(threshold=3.0)    cusum.fit(y)    cusum_changepoints = cusum.predict(y)        print(f"CUSUM change points: {cusum_changepoints.sum()}")except Exception as e:    print(f"CUSUM not available: {e}")

# %% [markdown]
# ## Visualization

# %% [raw]
# # Visualize change pointsplt.figure(figsize=(14, 6))plt.plot(y.index, y.values, label='Time Series', linewidth=2)if 'changepoints' in locals():    cp_indices = y.index[changepoints]    for cp in cp_indices:        plt.axvline(cp, color='red', linestyle='--', alpha=0.7, label='Change Point')plt.legend()plt.title('Change Point Detection')plt.grid(True, alpha=0.3)plt.tight_layout()plt.show()
