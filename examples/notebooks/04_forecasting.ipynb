# %% [markdown]
# # ForecastingThis notebook demonstrates various forecasting methods in TimeSmith.

# %% [raw]
# import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport timesmith as ts

# %% [markdown]
# ## Simple Moving Average

# %% [raw]
# # Create datadates = pd.date_range('2020-01-01', periods=200, freq='D')y = pd.Series(np.random.randn(200).cumsum() + 100, index=dates)# Moving average forecasterforecaster = ts.SimpleMovingAverageForecaster(window=7)forecaster.fit(y)forecast = forecaster.predict(fh=30)print(f"Forecast shape: {forecast.predicted.shape}")

# %% [markdown]
# ## Exponential Smoothing

# %% [raw]
# # Exponential smoothinges_forecaster = ts.ExponentialSmoothingForecaster()es_forecaster.fit(y)es_forecast = es_forecaster.predict(fh=30)print(f"ES Forecast shape: {es_forecast.predicted.shape}")

# %% [markdown]
# ## ARIMA

# %% [raw]
# # ARIMA forecaster (if available)try:    arima = ts.ARIMAForecaster()    arima.fit(y)    arima_forecast = arima.predict(fh=30)    print(f"ARIMA Forecast shape: {arima_forecast.predicted.shape}")except Exception as e:    print(f"ARIMA not available: {e}")

# %% [markdown]
# ## Monte Carlo Forecasting

# %% [raw]
# # Monte Carlo forecastermc_forecaster = ts.MonteCarloForecaster(n_simulations=1000)mc_forecaster.fit(y)mc_forecast = mc_forecaster.predict(fh=30)print(f"MC Forecast shape: {mc_forecast.predicted.shape}")if mc_forecast.intervals is not None:    print(f"Confidence intervals: {mc_forecast.intervals.keys()}")

# %% [markdown]
# ## Visualizing Forecasts

# %% [raw]
# # Compare forecastsplt.figure(figsize=(14, 6))plt.plot(y.index[-50:], y.values[-50:], label='Historical', linewidth=2)plt.plot(forecast.predicted.index, forecast.predicted.values, label='MA', linestyle='--')plt.plot(es_forecast.predicted.index, es_forecast.predicted.values, label='ES', linestyle='--')if mc_forecast.intervals is not None:    plt.fill_between(mc_forecast.predicted.index,                     mc_forecast.intervals['lower'].values,                     mc_forecast.intervals['upper'].values,                     alpha=0.3, label='MC 95% CI')plt.legend()plt.title('Forecast Comparison')plt.grid(True, alpha=0.3)plt.tight_layout()plt.show()
